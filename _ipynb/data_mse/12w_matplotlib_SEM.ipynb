# %%
#%matplotlib widget
# %matplotlib inline

# %%
# !pip install Pillow numpy matplotlib scikit-learn scikit-image
# Out:
# Requirement already satisfied: Pillow in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (10.2.0)
# Requirement already satisfied: numpy in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (3.8.3)
# Requirement already satisfied: scikit-learn in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (1.7.1)
# Requirement already satisfied: scikit-image in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (0.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-image) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: six>=1.5 in /Users/youngung/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from PIL import Image
import skimage
from skimage import io, color
import numpy as np
import matplotlib.pyplot as plt

# %%
# 5x5 랜덤 배열
data = np.random.rand(5, 5)

plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar()  # 값과 색의 대응 막대 추가
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 100x100 배열: 0~3 값 (가상의 결정립 영역)
grain_map = np.random.randint(0, 255, (100, 100))

fig=plt.figure(figsize=(8,2))
ax1=fig.add_subplot(131)
ax2=fig.add_subplot(132)
ax3=fig.add_subplot(133)
ax1.hist(grain_map.flatten())# histogram
cmaps=['jet','gray']
for i, ax in enumerate([ax2,ax3]):
    ax.imshow(grain_map, cmap=cmaps[i])
    ax.set_title(f'color map: {cmaps[i]}')

# %% [markdown]
# - PIL based image

# %%
fn='/Users/youngung/Library/CloudStorage/OneDrive-창원대학교/Works-Manuscripts/MyPapers_Working/numisheet_benchmark/sem.png'

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

fn='../data/dualphase_sem.png'
img_rgba = Image.open(fn) ## PIL, RGBA
img_gray=img_rgba.convert('L')
img_gray=np.asarray(img_gray)
plt.imshow(img_gray,cmap='gray')

# %%
flg=img>img.mean()

# %%
img=Image.open('../data/dualphase_sem.png')

img=np.asarray(img)
print(img.shape)
fig=plt.figure(figsize=(7,4))
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax4=fig.add_subplot(224)
ax1.hist(img.flatten())
ax2.imshow(img,cmap='gray')

newimg=img.copy()
flg=img>img.mean()
newimg[flg]=255
newimg[~flg]=0
h=ax3.hist(newimg.flatten())
ax4.imshow(newimg,cmap='gray')
for i, ax in enumerate([ax1,ax3]):
    ax.set_ylim(0,300000)

white,black=h[0][0],h[0][-1]
ferrite=white/(white+black)
martensite=black/(white+black)
print(ferrite,martensite)
# Out:
# (546, 838)
# 0.6181121980644654 0.3818878019355346

# %%
fn='../data/centercenter.png'
img=Image.open(fn)

img=np.asarray(img)
print(img.shape)
fig=plt.figure(figsize=(7,4))
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax4=fig.add_subplot(224)
ax1.hist(img.flatten())
ax2.imshow(img,cmap='gray')

newimg=img.copy()
flg=img>img.mean()
newimg[flg]=255
newimg[~flg]=0
h=ax3.hist(newimg.flatten())
ax4.imshow(newimg,cmap='gray')
for i, ax in enumerate([ax1,ax3]):
    ax.set_ylim(0,300000)

white,black=h[0][0],h[0][-1]
ferrite=white/(white+black)
martensite=black/(white+black)
print(ferrite,martensite)
# Out:
# (595, 842, 4)
# 0.5687523703067926 0.43124762969320746

# %%
# Out:
# 0.6181121980644654 0.3818878019355346
