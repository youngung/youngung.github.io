# %%
#%matplotlib widget
# %matplotlib inline

# %%
# !pip install periodictable
import periodictable
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.1/811.1 kB 16.0 MB/s  0:00:00
# ...

# %%
help(periodictable)
# Out:
# Help on package periodictable:
#
# NAME
#     periodictable - Extensible periodic table of elements
#
# DESCRIPTION
#     The periodictable package contains mass for the isotopes and density for the
#     elements. It calculates xray and neutron scattering information for
#     isotopes and elements. Composite values can be calculated from
#     chemical formula and density.
#
#     The table is extensible. See the user manual for details.
#
#     ----
#
#     Disclaimer:
#
#     This data has been compiled from a variety of sources for the user's
#     convenience and does not represent a critical evaluation by the authors.
#     While we have made efforts to verify that the values we use match
#     published values, the values themselves are based on measurements
#     whose conditions may differ from those of your experiment.
#
#     ----
#
# PACKAGE CONTENTS
#     activation
#     constants
#     core
#     covalent_radius
#     cromermann
#     crystal_structure
#     density
# ...

# %%
from periodictable import hydrogen, carbon, iron

# %%
print(iron.mass,iron.mass_units)
print(iron.density,iron.density_units)
# Out:
# 55.845 u
# 7.874 g/cm^3

# %%
def convert_a(wa,rhoa,rhob): ## get f_a
    return 1/(1+(100/wa-1)*(rhoa/rhob))*100
def convert_b(wa,rhoa,rhob): ## get f_a
    return 100-convert_a(wa,rhoa,rhob)
    #return 1/(1+(100/wb-1)*(rhob/rhoa))*100

# %%
wa=20
wb=30
rhoa=0.9
rhob=0.100

print(convert_a(wa,rhoa,rhob),convert_b(wa,rhoa,rhob))
# Out:
# 2.7027027027027026 97.29729729729729
