# %% [markdown]
# ```데이터 재료과학```

# %% [markdown]
# - 수업을 위한 필수 환경
#   + [Python](https://python.org)
#   + [JuPyter](https://jupyter.org)
#   + pip 설치, 필요시 인터넷 연결하여 Python package 설치 필요
#   + [MS VS code](https://code.visualstudio.com)
#
#   + (optional) [Google colaboratory](https://colab.research.google.com) 와 [Google Drive](https://drive.google.com/) 연계 사용 - Google 계정을 소유하고 있길 권장.
#
# - 각자의 컴퓨터에 환경을 직접 set-up 해야합니다.
#     + [창원대학교](https://changwon.ac.kr)
#     + 재료금속공학과
#     + [재료역학연구실](https://youngung.github.io)
#     + [정영웅](mailto:yjeong@changwon.ac.kr)
#
# - 참고: [Python reference](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb)

# %%
print('Hello, world')
# Out:
# Hello, world

# %%
## Markdown 과 code 탭 구분하기

# %% [markdown]
# # VS코드 기능
# - 아래 'JUPYTER' 탭 확인하기
# - Extension 확인하기
# - Agent 연결하여 활용가능
#   + chat

# %% [markdown]
# # Git
#  - 코드의 version control (기록/백업/collaboration 등등)
#  - AI시대를 맞이하는 대학생이라면 [GitHub](https://github.com) 계정 하나는 만들어두자.
